# %% [markdown]
# https://qiita.com/ysdyt/items/9ccca82fc5b504e7913a

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
set()
# Out:
# set()

# %%
df = pd.read_csv("../../Data/lunckbox.csv")
df
# Out:
#        datetime    y week  soldout            name   kcal          remarks  \
# 0    2013-11-18   90    月        0        厚切りイカフライ    NaN              NaN
# 1    2013-11-19  101    火        1         手作りヒレカツ    NaN              NaN
# 2    2013-11-20  118    水        0      白身魚唐揚げ野菜あん    NaN              NaN
# 3    2013-11-21  120    木        1          若鶏ピリ辛焼    NaN              NaN
# 4    2013-11-22  130    金        1        ビッグメンチカツ    NaN              NaN
# 5    2013-11-25  135    月        1            鶏の唐揚    NaN              NaN
# 6    2013-11-26  145    火        0        豚のスタミナ炒め    NaN              NaN
# 7    2013-11-27  140    水        1        ボローニャ風カツ    NaN              NaN
# 8    2013-11-28  151    木        0           ハンバーグ    NaN              NaN
# 9    2013-11-29  116    金        0   タルタルinソーセージカツ    NaN              NaN
# 10    2013-12-2  151    月        1           マーボ豆腐    NaN              NaN
# 11    2013-12-3  153    火        1        厚揚げ豚生姜炒め    NaN              NaN
# 12    2013-12-4  151    水        1    クリームチーズ入りメンチ    NaN              NaN
# 13    2013-12-5  171    木        0     鶏のカッシュナッツ炒め    NaN              NaN
# 14    2013-12-6  134    金        0        手作りロースカツ    NaN              NaN
# 15    2013-12-9  165    月        1      ハンバーグデミソース    NaN              NaN
# 16   2013-12-10  155    火        0   やわらかロースのサムジョン    NaN              NaN
# 17   2013-12-11  157    水        0            五目御飯    NaN              NaN
# 18   2013-12-12  109    木        0            肉じゃが    NaN              NaN
# 19   2013-12-13  111    金        1        タンドリーチキン    NaN              NaN
# 20   2013-12-16  160    月        0       カキフライタルタル    NaN              NaN
# 21   2013-12-17  145    火        0         手作りヒレカツ    NaN              NaN
# 22   2013-12-18  145    水        1             回鍋肉    NaN              NaN
# 23   2013-12-19  151    木        0         ポーク味噌焼き    NaN              NaN
# 24   2013-12-20  134    金        1       鶏の唐揚げ甘酢あん    NaN              NaN
# 25   2013-12-24  122    火        0       さっくりメンチカツ    NaN              NaN
# 26   2013-12-25  121    水        1       手ごね風ハンバーグ    NaN              NaN
# 27   2013-12-26   80    木        0              酢豚    NaN              NaN
# 28     2014-1-7  131    火        0    カレー入りソーセージカツ  404.0              NaN
# 29     2014-1-8  128    水        0          豚肉の生姜焼  462.0              NaN
# ..          ...  ...  ...      ...             ...    ...              ...
# 177   2014-8-18   56    月        0     洋食屋さんのメンチカツ  396.0              NaN
# 178   2014-8-19   53    火        1           牛スキヤキ  385.0              NaN
# 179   2014-8-20   56    水        0   豚ロースのピザ風チーズ焼き  423.0     料理長のこだわりメニュー
# 180   2014-8-21   54    木        0           チキン南蛮  405.0              NaN
# 181   2014-8-22  100    金        1           ロコモコ丼    NaN         お楽しみメニュー
# 182   2014-8-25   55    月        0        白身魚の南部焼き  412.0              NaN
# 183   2014-8-26   68    火        0          キーマカレー  400.0              NaN
# 184   2014-8-27   62    水        0         カレイの唐揚げ  410.0              NaN
# 185   2014-8-28   56    木        0        豚肉の胡麻シャブ  396.0              NaN
# 186   2014-8-29   39    金        0       チキンの辛味噌焼き  398.0              NaN
# 187    2014-9-1   65    月        1         ビーフシチュー  380.0              NaN
# 188    2014-9-2   68    火        1         名古屋味噌カツ  440.0            手作りの味
# 189    2014-9-3   53    水        0             親子煮  408.0              NaN
# 190    2014-9-4   54    木        1  チキンステーキ・きのこソース  405.0              NaN
# 191    2014-9-5   43    金        0           メンチカツ  380.0              NaN
# 192    2014-9-8   68    月        1         鶏肉の山賊焼き  385.0              NaN
# 193    2014-9-9   63    火        0      ハンバーグデミソース  460.0              NaN
# 194   2014-9-10   54    水        0     ぶりレモンペッパー焼き  450.0              NaN
# 195   2014-9-11   53    木        0        手作りチキンカツ  385.0              NaN
# 196   2014-9-12  115    金        0          ポークカレー    NaN         お楽しみメニュー
# 197   2014-9-16   56    火        0        チーズメンチカツ  438.0              NaN
# 198   2014-9-17   49    水        0        チキンフリカッセ  430.0     料理長のこだわりメニュー
# 199   2014-9-18   46    木        0     カレイ唐揚げ 甘酢あん  395.0              NaN
# 200   2014-9-19   45    金        0         厚切イカフライ  400.0              NaN
# 201   2014-9-22   29    月        0             筑前煮  395.0              NaN
# 202   2014-9-24   59    水        1     白身魚のマスタード焼き  408.0              NaN
# 203   2014-9-25   50    木        0         牛カルビ焼き肉  394.0              NaN
# 204   2014-9-26   45    金        0        ランチビュッフェ    NaN  スペシャルメニュー（800円）
# 205   2014-9-29   56    月        1        豚肉と玉子の炒め  404.0              NaN
# 206   2014-9-30   40    火        0    鶏肉とカシューナッツ炒め  398.0              NaN
#
#              event  payday weather precipitation  temperature
# 0              NaN     NaN      快晴            --         19.8
# 1              NaN     NaN      快晴            --         17.0
# 2              NaN     NaN      快晴            --         15.5
# 3              NaN     NaN      快晴            --         15.2
# 4              NaN     NaN      快晴            --         16.1
# 5              NaN     NaN       曇            --         14.6
# 6              NaN     NaN      快晴            --         17.9
# 7              NaN     NaN      晴れ            --         14.7
# 8              NaN     NaN      薄曇            --         17.7
# 9              NaN     NaN      快晴            --         12.1
# 10             NaN     NaN      快晴            --         13.8
# 11             NaN     NaN      快晴            --         13.9
# 12             NaN     NaN      晴れ            --         13.5
# 13             NaN     NaN      快晴            --         13.8
# 14             NaN     NaN      快晴            --         14.9
# 15             NaN     NaN       曇            --          9.1
# 16             NaN     1.0       曇           0.5          7.1
# 17             NaN     NaN       曇            --         11.0
# 18             NaN     NaN      快晴            --         12.3
# 19             NaN     NaN      快晴            --         13.9
# 20             NaN     NaN      快晴            --         11.3
# 21            ママの会     NaN       曇            --         10.8
# 22             NaN     NaN       曇            --          7.8
# 23             NaN     NaN       雨           0.5          6.8
# 24             NaN     NaN       曇            --          8.4
# 25             NaN     NaN      快晴            --         11.5
# 26             NaN     NaN      快晴            --          8.0
# 27             NaN     NaN       曇            --          7.3
# 28             NaN     NaN      快晴            --          7.3
# 29             NaN     NaN       曇            --          9.8
# ..             ...     ...     ...           ...          ...
# 177            NaN     NaN       曇            --         32.2
# 178            NaN     NaN      晴れ            --         33.3
# 179           ママの会     NaN      快晴            --         33.3
# 180  キャリアアップ支援セミナー     NaN      薄曇            --         33.0
# 181            NaN     NaN      晴れ            --         33.1
# 182            NaN     NaN       曇             0         26.0
# 183            NaN     NaN       雨             0         26.2
# 184            NaN     NaN       曇             0         21.0
# 185            NaN     NaN       雨             0         21.6
# 186            NaN     NaN       曇             0         25.1
# 187            NaN     NaN       曇            --         23.4
# 188            NaN     NaN      晴れ            --         29.1
# 189            NaN     NaN       曇            --         26.7
# 190            NaN     NaN       曇             0         26.5
# 191            NaN     NaN      晴れ            --         30.2
# 192            NaN     NaN       曇            --         23.1
# 193            NaN     NaN      晴れ            --         26.8
# 194            NaN     1.0       曇             0         25.0
# 195            NaN     NaN       曇            --         21.9
# 196            NaN     NaN      晴れ            --         27.3
# 197            NaN     NaN      晴れ            --         28.8
# 198           ママの会     NaN       曇            --         25.0
# 199            NaN     NaN       曇            --         24.1
# 200            NaN     NaN      薄曇            --         23.6
# 201            NaN     NaN      晴れ            --         25.2
# 202            NaN     NaN       曇             0         24.8
# 203            NaN     NaN       曇             0         25.4
# 204  キャリアアップ支援セミナー     NaN      晴れ            --         27.1
# 205            NaN     NaN      快晴            --         26.6
# 206            NaN     NaN      快晴            --         28.1
#
# [207 rows x 12 columns]

# %% [markdown]
# | No | 列       | 内容 | 説明   |
# |----|----------|------|--------|
# | 1  | datetime |日付  |インデックス|
# | 2  | y |販売数  |目的変数|
# | 3  | week |曜日  |月～金|
# | 4  | soldout |完売フラグ  |1:完売|
# | 5  | name |メニュー  |日本語メニュー|
# | 6  | kcal |カロリー  |整数|
# | 7  | remark |特記事項  |自由記述|
# | 8  | event |弁当持ち込みイベント  |社内イベント|
# | 9  | payday |給料日  |1:給料日|
# | 10  | weather |天気  |日本語天気|
# | 11  | precipiation |降水量  |実数|
# | 12  | temperature |気温  |実数|

# %%
# 先頭の5行を表示
df.head()
# Out:
#      datetime    y week  soldout        name  kcal remarks event  payday  \
# 0  2013-11-18   90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN
# 1  2013-11-19  101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN
# 2  2013-11-20  118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN
# 3  2013-11-21  120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN
# 4  2013-11-22  130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN
#
#   weather precipitation  temperature
# 0      快晴            --         19.8
# 1      快晴            --         17.0
# 2      快晴            --         15.5
# 3      快晴            --         15.2
# 4      快晴            --         16.1

# %%
# 最後尾の5行を表示
df.tail()
# Out:
#       datetime   y week  soldout          name   kcal          remarks  \
# 202  2014-9-24  59    水        1   白身魚のマスタード焼き  408.0              NaN
# 203  2014-9-25  50    木        0       牛カルビ焼き肉  394.0              NaN
# 204  2014-9-26  45    金        0      ランチビュッフェ    NaN  スペシャルメニュー（800円）
# 205  2014-9-29  56    月        1      豚肉と玉子の炒め  404.0              NaN
# 206  2014-9-30  40    火        0  鶏肉とカシューナッツ炒め  398.0              NaN
#
#              event  payday weather precipitation  temperature
# 202            NaN     NaN       曇             0         24.8
# 203            NaN     NaN       曇             0         25.4
# 204  キャリアアップ支援セミナー     NaN      晴れ            --         27.1
# 205            NaN     NaN      快晴            --         26.6
# 206            NaN     NaN      快晴            --         28.1

# %%
# 簡単にデータの状態を確認する（行数列数カウント・データの選択的表示・重複の有無など）
print('dataframeの行数・列数の確認==>\n', df.shape, "\n")
print('indexの確認==>\n', df.index, "\n")
print('columnの確認==>\n', df.columns, "\n")
print('dataframeの各列のデータ型を確認==>\n', df.dtypes)
# Out:
# dataframeの行数・列数の確認==>
#  (207, 12)
#
# indexの確認==>
#  RangeIndex(start=0, stop=207, step=1)
#
# columnの確認==>
#  Index(['datetime', 'y', 'week', 'soldout', 'name', 'kcal', 'remarks', 'event',
#        'payday', 'weather', 'precipitation', 'temperature'],
#       dtype='object')
#
# dataframeの各列のデータ型を確認==>
#  datetime          object
# y                  int64
# week              object
# soldout            int64
# name              object
# kcal             float64
# remarks           object
# event             object
# payday           float64
# weather           object
# precipitation     object
# temperature      float64
# dtype: object

# %%
# 任意の列だけ取り出したい場合
df[['name', 'kcal']].head()
# Out:
#          name  kcal
# 0    厚切りイカフライ   NaN
# 1     手作りヒレカツ   NaN
# 2  白身魚唐揚げ野菜あん   NaN
# 3      若鶏ピリ辛焼   NaN
# 4    ビッグメンチカツ   NaN

# %%
# 100行目から105行目まで表示したい場合
df[100:106]
# Out:
#       datetime   y week  soldout      name   kcal   remarks event  payday  \
# 100  2014-4-22  78    火        1     マーボ豆腐  382.0       NaN   NaN     NaN
# 101  2014-4-23  63    水        0   手作りひれかつ  340.0       NaN   NaN     NaN
# 102  2014-4-24  56    木        1  鶏の照り焼きマヨ  360.0       NaN   NaN     NaN
# 103  2014-4-25  80    金        0       中華丼    NaN  お楽しみメニュー   NaN     NaN
# 104  2014-4-28  54    月        0  タンドリーチキン  342.0       NaN   NaN     NaN
# 105  2014-4-30  97    水        1  豚味噌メンチカツ  368.0       NaN   NaN     NaN
#
#     weather precipitation  temperature
# 100       曇            --         18.8
# 101      快晴            --         19.4
# 102      晴れ            --         19.9
# 103      晴れ            --         20.8
# 104      晴れ            --         22.7
# 105       雨           0.5         17.5

# %%
# indexが100の行だけ取得したい場合
df.loc[100]
# Out:
# datetime         2014-4-22
# y                       78
# week                     火
# soldout                  1
# name                 マーボ豆腐
# kcal                   382
# remarks                NaN
# event                  NaN
# payday                 NaN
# weather                  曇
# precipitation           --
# temperature           18.8
# Name: 100, dtype: object

# %%
# もっとピンポイントに抽出したい場合
# 例: 1,2,4 行目と 0-2 列目を取得
df.iloc[[1,2,4],[0,2]]
# Out:
#      datetime week
# 1  2013-11-19    火
# 2  2013-11-20    水
# 4  2013-11-22    金

# %%
# 条件を指定して抽出
df[df['kcal'] > 450]
# Out:
#       datetime    y week  soldout        name   kcal remarks event  payday  \
# 29    2014-1-8  128    水        0      豚肉の生姜焼  462.0     NaN   NaN     NaN
# 45   2014-1-31   92    金        1      メダイ照り焼  460.0     NaN   NaN     NaN
# 193   2014-9-9   63    火        0  ハンバーグデミソース  460.0     NaN   NaN     NaN
#
#     weather precipitation  temperature
# 29        曇            --          9.8
# 45       快晴            --         14.1
# 193      晴れ            --         26.8

# %%
# queryメソッドを使うと、複数条件の指定で、特定カラムだけ出力もできる
df[['name', 'kcal']].query('kcal > 450 and name == "豚肉の生姜焼"') #query内のシングル/ダブルクオーテーションの使い方に注意
# Out:
#       name   kcal
# 29  豚肉の生姜焼  462.0

# %%
# 'remarks(備考)'には例えばどんなデータが入っているか確認
df['remarks'].unique()
# Out:
# array([nan, '鶏のレモンペッパー焼（50食）、カレー（42食）', '酢豚（28食）、カレー（85食）', 'お楽しみメニュー',
#        '料理長のこだわりメニュー', '手作りの味', 'スペシャルメニュー（800円）'], dtype=object)

# %%
# datatime単位で重複したデータが存在しないか確認
print(len(df) == len(df['datetime'].unique()))
# Out:
# True

# %%
#行方向で重複行を削除
df.drop_duplicates() 
print(df.shape) # 重複が存在しないので数は変わらないはず
# Out:
# (207, 12)

# %%
# 要約統計量の表示
df.describe()
# Out:
#                 y     soldout        kcal  payday  temperature
# count  207.000000  207.000000  166.000000    10.0   207.000000
# mean    86.623188    0.449275  404.409639     1.0    19.252174
# std     32.882448    0.498626   29.884641     0.0     8.611365
# min     29.000000    0.000000  315.000000     1.0     1.200000
# 25%     57.000000    0.000000  386.000000     1.0    11.550000
# 50%     78.000000    0.000000  408.500000     1.0    19.800000
# 75%    113.000000    1.000000  426.000000     1.0    26.100000
# max    171.000000    1.000000  462.000000     1.0    34.600000

# %%
# datetime列をindexにする
df.set_index('datetime', inplace=True)
df.head()
# Out:
#               y week  soldout        name  kcal remarks event  payday weather  \
# datetime
# 2013-11-18   90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN      快晴
# 2013-11-19  101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN      快晴
# 2013-11-20  118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN      快晴
# 2013-11-21  120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN      快晴
# 2013-11-22  130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN      快晴
#
#            precipitation  temperature
# datetime
# 2013-11-18            --         19.8
# 2013-11-19            --         17.0
# 2013-11-20            --         15.5
# 2013-11-21            --         15.2
# 2013-11-22            --         16.1

# %%
# カラム名を変更する（y を sales に変換）
df.rename(columns={'y': 'sales'}, inplace=True)
df.head()
# Out:
#             sales week  soldout        name  kcal remarks event  payday  \
# datetime
# 2013-11-18     90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN
# 2013-11-19    101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN
# 2013-11-20    118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN
# 2013-11-21    120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN
# 2013-11-22    130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN
#
#            weather precipitation  temperature
# datetime
# 2013-11-18      快晴            --         19.8
# 2013-11-19      快晴            --         17.0
# 2013-11-20      快晴            --         15.5
# 2013-11-21      快晴            --         15.2
# 2013-11-22      快晴            --         16.1

# %%
# 'sales'列を降順で並び替えもできる
df.sort_values(by="sales", ascending=True).head() # ascending=Trueで昇順
# Out:
#            sales week  soldout          name   kcal remarks event  payday  \
# datetime
# 2014-9-22     29    月        0           筑前煮  395.0     NaN   NaN     NaN
# 2014-8-1      38    金        0       豚肉の生姜焼き  380.0     NaN   NaN     NaN
# 2014-8-29     39    金        0     チキンの辛味噌焼き  398.0     NaN   NaN     NaN
# 2014-9-30     40    火        0  鶏肉とカシューナッツ炒め  398.0     NaN   NaN     NaN
# 2014-8-12     40    火        1        厚切ハムカツ  400.0     NaN   NaN     NaN
#
#           weather precipitation  temperature
# datetime
# 2014-9-22      晴れ            --         25.2
# 2014-8-1       薄曇            --         32.7
# 2014-8-29       曇             0         25.1
# 2014-9-30      快晴            --         28.1
# 2014-8-12       雨             0         29.4

# %%
# sort_valuesは複数の列に対しても実行できる
df.sort_values(['sales', 'temperature'], ascending=False).head() # ascending=Falseで昇順
# Out:
#             sales week  soldout           name  kcal remarks event  payday  \
# datetime
# 2013-12-5     171    木        0    鶏のカッシュナッツ炒め   NaN     NaN   NaN     NaN
# 2013-12-9     165    月        1     ハンバーグデミソース   NaN     NaN   NaN     NaN
# 2013-12-16    160    月        0      カキフライタルタル   NaN     NaN   NaN     NaN
# 2013-12-11    157    水        0           五目御飯   NaN     NaN   NaN     NaN
# 2013-12-10    155    火        0  やわらかロースのサムジョン   NaN     NaN   NaN     1.0
#
#            weather precipitation  temperature
# datetime
# 2013-12-5       快晴            --         13.8
# 2013-12-9        曇            --          9.1
# 2013-12-16      快晴            --         11.3
# 2013-12-11       曇            --         11.0
# 2013-12-10       曇           0.5          7.1

# %%
# indexのデータ型を確認してみる
df.index #  dtype='object'であることがわかる
# Out:
# Index(['2013-11-18', '2013-11-19', '2013-11-20', '2013-11-21', '2013-11-22',
#        '2013-11-25', '2013-11-26', '2013-11-27', '2013-11-28', '2013-11-29',
#        ...
#        '2014-9-16', '2014-9-17', '2014-9-18', '2014-9-19', '2014-9-22',
#        '2014-9-24', '2014-9-25', '2014-9-26', '2014-9-29', '2014-9-30'],
#       dtype='object', name='datetime', length=207)

# %%
# indexであるdatetimeのdtype='object' を dtype='datetime64[ns]' に変更
df.index = pd.to_datetime(df.index, format='%Y-%m-%d')
df.index
# Out:
# DatetimeIndex(['2013-11-18', '2013-11-19', '2013-11-20', '2013-11-21',
#                '2013-11-22', '2013-11-25', '2013-11-26', '2013-11-27',
#                '2013-11-28', '2013-11-29',
#                ...
#                '2014-09-16', '2014-09-17', '2014-09-18', '2014-09-19',
#                '2014-09-22', '2014-09-24', '2014-09-25', '2014-09-26',
#                '2014-09-29', '2014-09-30'],
#               dtype='datetime64[ns]', name='datetime', length=207, freq=None)

# %%
# indexに対してsortを行う
df.sort_index().head() # object型のままだと正しくsortされない
# Out:
#             sales week  soldout        name  kcal remarks event  payday  \
# datetime
# 2013-11-18     90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN
# 2013-11-19    101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN
# 2013-11-20    118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN
# 2013-11-21    120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN
# 2013-11-22    130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN
#
#            weather precipitation  temperature
# datetime
# 2013-11-18      快晴            --         19.8
# 2013-11-19      快晴            --         17.0
# 2013-11-20      快晴            --         15.5
# 2013-11-21      快晴            --         15.2
# 2013-11-22      快晴            --         16.1

# %%
# resampleメソッドで、日単位や月単位で簡単に集計できる
df.resample('M').mean() #月単位で平均値を出力
# Out:
#                  sales   soldout        kcal  payday  temperature
# datetime
# 2013-11-30  124.600000  0.500000         NaN     NaN    16.060000
# 2013-12-31  139.722222  0.444444         NaN     1.0    10.844444
# 2014-01-31  115.222222  0.611111  427.555556     1.0     8.716667
# 2014-02-28  107.842105  0.526316  420.947368     1.0     7.815789
# 2014-03-31   89.350000  0.450000  382.157895     1.0    12.505000
# 2014-04-30   85.761905  0.476190  360.000000     1.0    18.176190
# 2014-05-31   74.200000  0.550000  419.111111     1.0    22.505000
# 2014-06-30   67.285714  0.333333  423.315789     1.0    25.409524
# 2014-07-31   61.363636  0.454545  397.200000     1.0    29.350000
# 2014-08-31   61.166667  0.333333  403.187500     1.0    30.227778
# 2014-09-30   55.550000  0.300000  408.611111     1.0    25.935000

# %%
# 簡単にmonth列やday列を作れるようになる
df['month'] = list(pd.Series(df.index).apply(lambda x: x.month))
df['day'] = list(pd.Series(df.index).apply(lambda x: x.day))

df.head()
# Out:
#             sales week  soldout        name  kcal remarks event  payday  \
# datetime
# 2013-11-18     90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN
# 2013-11-19    101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN
# 2013-11-20    118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN
# 2013-11-21    120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN
# 2013-11-22    130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN
#
#            weather precipitation  temperature  month  day
# datetime
# 2013-11-18      快晴            --         19.8     11   18
# 2013-11-19      快晴            --         17.0     11   19
# 2013-11-20      快晴            --         15.5     11   20
# 2013-11-21      快晴            --         15.2     11   21
# 2013-11-22      快晴            --         16.1     11   22

# %%
# cutメソッドでヒストグラムのビン指定的な処理ができる
labels = ['上旬', '中旬', '下旬']
df['period'] = pd.cut(list(df['day']),  bins=[0,10,20,31], labels=labels, right=True) # 0<day≦10, 10<day≦20, 20<day≦31

df.head()
# Out:
#             sales week  soldout        name  kcal remarks event  payday  \
# datetime
# 2013-11-18     90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN
# 2013-11-19    101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN
# 2013-11-20    118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN
# 2013-11-21    120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN
# 2013-11-22    130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN
#
#            weather precipitation  temperature  month  day period
# datetime
# 2013-11-18      快晴            --         19.8     11   18     中旬
# 2013-11-19      快晴            --         17.0     11   19     中旬
# 2013-11-20      快晴            --         15.5     11   20     中旬
# 2013-11-21      快晴            --         15.2     11   21     下旬
# 2013-11-22      快晴            --         16.1     11   22     下旬

# %%
# 列単位で 欠損値NaN(not a number)が入っている個数をカウントする （正確には、isnull()でtureが返ってくる個数をカウントしている）
df.isnull().sum()
# Out:
# sales              0
# week               0
# soldout            0
# name               0
# kcal              41
# remarks          186
# event            193
# payday           197
# weather            0
# precipitation      0
# temperature        0
# month              0
# day                0
# period             0
# dtype: int64

# %%
# 1つでもNaNが含まれる行だけを抽出（最初の5行のみ表示）
print(df[df.isnull().any(axis=1)].shape)
df[df.isnull().any(axis=1)].head()
# Out:
# (207, 14)
#             sales week  soldout        name  kcal remarks event  payday  \
# datetime
# 2013-11-18     90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN
# 2013-11-19    101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN
# 2013-11-20    118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN
# 2013-11-21    120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN
# 2013-11-22    130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN
#
#            weather precipitation  temperature  month  day period
# datetime
# 2013-11-18      快晴            --         19.8     11   18     中旬
# 2013-11-19      快晴            --         17.0     11   19     中旬
# 2013-11-20      快晴            --         15.5     11   20     中旬
# 2013-11-21      快晴            --         15.2     11   21     下旬
# 2013-11-22      快晴            --         16.1     11   22     下旬

# %%
# 'payday'列にあるNaNを'0.0'に置き換える
df.fillna(value={'payday': 0.0}, inplace=True)
df.head()
# Out:
#             sales week  soldout        name  kcal remarks event  payday  \
# datetime
# 2013-11-18     90    月        0    厚切りイカフライ   NaN     NaN   NaN     0.0
# 2013-11-19    101    火        1     手作りヒレカツ   NaN     NaN   NaN     0.0
# 2013-11-20    118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     0.0
# 2013-11-21    120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     0.0
# 2013-11-22    130    金        1    ビッグメンチカツ   NaN     NaN   NaN     0.0
#
#            weather precipitation  temperature  month  day period
# datetime
# 2013-11-18      快晴            --         19.8     11   18     中旬
# 2013-11-19      快晴            --         17.0     11   19     中旬
# 2013-11-20      快晴            --         15.5     11   20     中旬
# 2013-11-21      快晴            --         15.2     11   21     下旬
# 2013-11-22      快晴            --         16.1     11   22     下旬

# %%
df.isnull().sum() # 'payday'が0になった
# Out:
# sales              0
# week               0
# soldout            0
# name               0
# kcal              41
# remarks          186
# event            193
# payday             0
# weather            0
# precipitation      0
# temperature        0
# month              0
# day                0
# period             0
# dtype: int64

# %%
# 'kcal'列にNaNがある行を削除する
df.dropna(subset=['kcal'], axis=0, inplace=True)
print(df.shape) # 207-166=41行のデータを削除した
# Out:
# (166, 14)

# %%
df.isnull().sum() # kcal'がNaNがなくなって0になっていることがわかる
# Out:
# sales              0
# week               0
# soldout            0
# name               0
# kcal               0
# remarks          158
# event            155
# payday             0
# weather            0
# precipitation      0
# temperature        0
# month              0
# day                0
# period             0
# dtype: int64

# %%
# 'precipitation' 列の '--' を 0に置き換える
df['precipitation'] = df['precipitation'].replace('--', 0).astype(float)
df.head()
# Out:
#             sales week  soldout          name   kcal remarks event  payday  \
# datetime
# 2014-01-07    131    火        0  カレー入りソーセージカツ  404.0     NaN   NaN     0.0
# 2014-01-08    128    水        0        豚肉の生姜焼  462.0     NaN   NaN     0.0
# 2014-01-09    129    木        1        鶏チリソース  435.0     NaN   NaN     0.0
# 2014-01-10     87    金        0      手作りロースカツ  440.0     NaN   NaN     1.0
# 2014-01-14    129    火        1   鶏の照り焼きマスタード  376.0     NaN   NaN     0.0
#
#            weather  precipitation  temperature  month  day period
# datetime
# 2014-01-07      快晴            0.0          7.3      1    7     上旬
# 2014-01-08       曇            0.0          9.8      1    8     上旬
# 2014-01-09       曇            0.0         10.9      1    9     上旬
# 2014-01-10      快晴            0.0          5.1      1   10     上旬
# 2014-01-14      晴れ            0.0          5.8      1   14     中旬

# %%
# maskメソッドを使う例。'sales'列が80よりも大きければ、その値を100に置換する
pd.DataFrame(df['sales'].mask(df['sales'] > 80, 100)).head()
# Out:
#             sales
# datetime
# 2014-01-07    100
# 2014-01-08    100
# 2014-01-09    100
# 2014-01-10    100
# 2014-01-14    100

# %%
# 'remarks(備考)'はデータとして不要な気がするので、データから列ごと削除
df.drop(['remarks'], axis=1, inplace=True)
df.head()
# Out:
#             sales week  soldout          name   kcal event  payday weather  \
# datetime
# 2014-01-07    131    火        0  カレー入りソーセージカツ  404.0   NaN     0.0      快晴
# 2014-01-08    128    水        0        豚肉の生姜焼  462.0   NaN     0.0       曇
# 2014-01-09    129    木        1        鶏チリソース  435.0   NaN     0.0       曇
# 2014-01-10     87    金        0      手作りロースカツ  440.0   NaN     1.0      快晴
# 2014-01-14    129    火        1   鶏の照り焼きマスタード  376.0   NaN     0.0      晴れ
#
#             precipitation  temperature  month  day period
# datetime
# 2014-01-07            0.0          7.3      1    7     上旬
# 2014-01-08            0.0          9.8      1    8     上旬
# 2014-01-09            0.0         10.9      1    9     上旬
# 2014-01-10            0.0          5.1      1   10     上旬
# 2014-01-14            0.0          5.8      1   14     中旬

# %%
# weather列の集計
df['weather'].value_counts()
# Out:
# 曇     44
# 晴れ    41
# 快晴    34
# 薄曇    23
# 雨     22
# 雷電     1
# 雪      1
# Name: weather, dtype: int64

# %%
# groupbyメソッドで、'week'列ごとに'soldout'の数をカウントする
df.groupby(['week'])['soldout'].count()
# Out:
# week
# 月    34
# 木    37
# 水    37
# 火    35
# 金    23
# Name: soldout, dtype: int64

# %%
# groupbyメソッドは複数列に対しても行える
# groupbyメソッドで、'month', 'period'列ごとに'sales'の数を合計する
df.groupby(['month', 'period'])['sales'].sum()
# Out:
# month  period
# 1      上旬         475
#        中旬         581
#        下旬        1018
# 2      上旬         725
#        中旬         715
#        下旬         609
# 3      上旬         614
#        中旬         698
#        下旬         369
# 4      上旬         792
#        中旬         344
#        下旬         457
# 5      上旬         316
#        中旬         406
#        下旬         517
# 6      上旬         467
#        中旬         440
#        下旬         311
# 7      上旬         460
#        中旬         277
#        下旬         406
# 8      上旬         288
#        中旬         250
#        下旬         334
# 9      上旬         468
#        中旬         249
#        下旬         234
# Name: sales, dtype: int64

# %%
# wetherごとにtemperatureの平均値を出す
df.groupby(['weather'])['temperature'].mean()
# Out:
# weather
# 快晴    15.294118
# 晴れ    22.558537
# 曇     19.377273
# 薄曇    23.926087
# 雨     18.813636
# 雪      1.200000
# 雷電    19.000000
# Name: temperature, dtype: float64

# %%
# 前行との差分が欲しい時は .diff() を使う
df['temperature_diff'] = df['temperature'].diff(periods=1)
df[['temperature','temperature_diff']].head()
# Out:
#             temperature  temperature_diff
# datetime
# 2014-01-07          7.3               NaN
# 2014-01-08          9.8               2.5
# 2014-01-09         10.9               1.1
# 2014-01-10          5.1              -5.8
# 2014-01-14          5.8               0.7

# %%
# 'temperature'列について、頭からwindowサイズ3で移動平均を計算する
df['temperature_rolling_mean'] = df['temperature'].rolling(window=3).mean()
df[['temperature', 'temperature_diff', 'temperature_rolling_mean']].head()
# Out:
#             temperature  temperature_diff  temperature_rolling_mean
# datetime
# 2014-01-07          7.3               NaN                       NaN
# 2014-01-08          9.8               2.5                       NaN
# 2014-01-09         10.9               1.1                  9.333333
# 2014-01-10          5.1              -5.8                  8.600000
# 2014-01-14          5.8               0.7                  7.266667

# %%
df['temperature_pct_change'] = df['temperature'].pct_change()
df[['temperature', 'temperature_diff', 'temperature_rolling_mean', 'temperature_pct_change']].head()
# Out:
#             temperature  temperature_diff  temperature_rolling_mean  \
# datetime
# 2014-01-07          7.3               NaN                       NaN
# 2014-01-08          9.8               2.5                       NaN
# 2014-01-09         10.9               1.1                  9.333333
# 2014-01-10          5.1              -5.8                  8.600000
# 2014-01-14          5.8               0.7                  7.266667
#
#             temperature_pct_change
# datetime
# 2014-01-07                     NaN
# 2014-01-08                0.342466
# 2014-01-09                0.112245
# 2014-01-10               -0.532110
# 2014-01-14                0.137255

# %%
# 'temperature'列に一つでもNaNがある行を削除
df.dropna(subset=['temperature_diff', 'temperature_rolling_mean', 'temperature_pct_change'], axis=0, inplace=True)

# %%
# 改めて、各列にNaNが入っていないか確認
df.isnull().sum()
# Out:
# sales                         0
# week                          0
# soldout                       0
# name                          0
# kcal                          0
# event                       153
# payday                        0
# weather                       0
# precipitation                 0
# temperature                   0
# month                         0
# day                           0
# period                        0
# temperature_diff              0
# temperature_rolling_mean      0
# temperature_pct_change        0
# dtype: int64

# %%
df.head()
# Out:
#             sales week  soldout          name   kcal event  payday weather  \
# datetime
# 2014-01-09    129    木        1        鶏チリソース  435.0   NaN     0.0       曇
# 2014-01-10     87    金        0      手作りロースカツ  440.0   NaN     1.0      快晴
# 2014-01-14    129    火        1   鶏の照り焼きマスタード  376.0   NaN     0.0      晴れ
# 2014-01-15    134    水        0        さんま辛味焼  450.0   NaN     0.0       曇
# 2014-01-16    107    木        0  カレイ唐揚げ野菜あんかけ  415.0   NaN     0.0      快晴
#
#             precipitation  temperature  month  day period  temperature_diff  \
# datetime
# 2014-01-09            0.0         10.9      1    9     上旬               1.1
# 2014-01-10            0.0          5.1      1   10     上旬              -5.8
# 2014-01-14            0.0          5.8      1   14     中旬               0.7
# 2014-01-15            0.0          2.9      1   15     中旬              -2.9
# 2014-01-16            0.0          7.0      1   16     中旬               4.1
#
#             temperature_rolling_mean  temperature_pct_change
# datetime
# 2014-01-09                  9.333333                0.112245
# 2014-01-10                  8.600000               -0.532110
# 2014-01-14                  7.266667                0.137255
# 2014-01-15                  4.600000               -0.500000
# 2014-01-16                  5.233333                1.413793

# %%
# 日本語フォントの設定
import matplotlib
font = {"family": "TakaoGothic"}
matplotlib.rc('font', **font)
plt.style.use('ggplot')

# %%
#超単純な折れ線グラフ
df['sales'].plot()

# %%
# 少しだけ情報量の多い折れ線グラフ
df.plot(y=['temperature', 'temperature_rolling_mean', 'temperature_pct_change'],  figsize=(16,4), alpha=0.5) # x軸がindexである場合は明記しなくても可
plt.title('気温変化に関する図', )
# Out:
# /home/yoshito/.pyenv/versions/3.6.1/lib/python3.6/site-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label
# Text(0.5,1,'気温変化に関する図')

# %%
# ヒストグラム
df.plot(kind='hist', y='sales' , bins=10, figsize=(16,4), alpha=0.5)

# %%
# 散布図
df.plot(kind='scatter', x='kcal', y='sales')

# %%
# ちなみに相関係数はcorrメソッドで簡単に表示できる
df[['kcal', 'sales']].corr()
# Out:
#            kcal     sales
# kcal   1.000000  0.129521
# sales  0.129521  1.000000

# %%
# ちょっとだけ複雑な集計 例: 月別・期間別の売上個数の状況を可視化したい場合
monthly_df = pd.DataFrame(df.groupby(['month', 'period'])['sales'].sum())
pivot_monthly_df = monthly_df.reset_index().pivot(index='month', columns='period', values='sales')
pivot_monthly_df
# Out:
# period   上旬   中旬    下旬
# month
# 1       216  581  1018
# 2       725  715   609
# 3       614  698   369
# 4       792  344   457
# 5       316  406   517
# 6       467  440   311
# 7       460  277   406
# 8       288  250   334
# 9       468  249   234

# %%
# 棒グラフ
pivot_monthly_df.plot(kind='bar', alpha=0.6, figsize=(12,3)).legend()
plt.title('月別・期間別の売上個数')
# Out:
# Text(0.5,1,'月別・期間別の売上個数')

# %%
# 現在のcolumnを確認
print(df.columns)
print(len(df.columns))
# Out:
# Index(['sales', 'week', 'soldout', 'name', 'kcal', 'event', 'payday',
#        'weather', 'precipitation', 'temperature', 'month', 'day', 'period',
#        'temperature_diff', 'temperature_rolling_mean',
#        'temperature_pct_change'],
#       dtype='object')
# 16

# %%
# テキストデータが入っている列全てをdummy化する
dummy_df = pd.get_dummies(df, columns=['week', 'name', 'event', 'weather', 'period'])
dummy_df.head()
# Out:
#             sales  soldout   kcal  payday  precipitation  temperature  month  \
# datetime
# 2014-01-09    129        1  435.0     0.0            0.0         10.9      1
# 2014-01-10     87        0  440.0     1.0            0.0          5.1      1
# 2014-01-14    129        1  376.0     0.0            0.0          5.8      1
# 2014-01-15    134        0  450.0     0.0            0.0          2.9      1
# 2014-01-16    107        0  415.0     0.0            0.0          7.0      1
#
#             day  temperature_diff  temperature_rolling_mean    ...      \
# datetime                                                       ...
# 2014-01-09    9               1.1                  9.333333    ...
# 2014-01-10   10              -5.8                  8.600000    ...
# 2014-01-14   14               0.7                  7.266667    ...
# 2014-01-15   15              -2.9                  4.600000    ...
# 2014-01-16   16               4.1                  5.233333    ...
#
#             weather_快晴  weather_晴れ  weather_曇  weather_薄曇  weather_雨  \
# datetime
# 2014-01-09           0           0          1           0          0
# 2014-01-10           1           0          0           0          0
# 2014-01-14           0           1          0           0          0
# 2014-01-15           0           0          1           0          0
# 2014-01-16           1           0          0           0          0
#
#             weather_雪  weather_雷電  period_上旬  period_中旬  period_下旬
# datetime
# 2014-01-09          0           0          1          0          0
# 2014-01-10          0           0          1          0          0
# 2014-01-14          0           0          0          1          0
# 2014-01-15          0           0          0          1          0
# 2014-01-16          0           0          0          1          0
#
# [5 rows x 157 columns]

# %%
# jupyter notebookにおいて、pandasで表示が省略されるのを防ぐ
pd.set_option('display.max_columns', 160) # 160番目の列まで全て強制表示

# %%
print(dummy_df.shape)
dummy_df.head()
# Out:
# (164, 157)
#             sales  soldout   kcal  payday  precipitation  temperature  month  \
# datetime
# 2014-01-09    129        1  435.0     0.0            0.0         10.9      1
# 2014-01-10     87        0  440.0     1.0            0.0          5.1      1
# 2014-01-14    129        1  376.0     0.0            0.0          5.8      1
# 2014-01-15    134        0  450.0     0.0            0.0          2.9      1
# 2014-01-16    107        0  415.0     0.0            0.0          7.0      1
#
#             day  temperature_diff  temperature_rolling_mean  \
# datetime
# 2014-01-09    9               1.1                  9.333333
# 2014-01-10   10              -5.8                  8.600000
# 2014-01-14   14               0.7                  7.266667
# 2014-01-15   15              -2.9                  4.600000
# 2014-01-16   16               4.1                  5.233333
#
#             temperature_pct_change  week_月  week_木  week_水  week_火  week_金  \
# datetime
# 2014-01-09                0.112245       0       1       0       0       0
# 2014-01-10               -0.532110       0       0       0       0       1
# 2014-01-14                0.137255       0       0       0       1       0
# 2014-01-15               -0.500000       0       0       1       0       0
# 2014-01-16                1.413793       0       1       0       0       0
#
#             name_いか天ぷら  name_かじきの甘辛煮  name_きのこソースハンバーグ  name_さわら焼味噌掛け  \
# datetime
# 2014-01-09           0             0                 0              0
# 2014-01-10           0             0                 0              0
# 2014-01-14           0             0                 0              0
# 2014-01-15           0             0                 0              0
# 2014-01-16           0             0                 0              0
#
#             name_さんま辛味焼  name_たっぷりベーコンフライ  name_ぶりレモンペッパー焼き  name_ますのマスタードソース  \
# datetime
# 2014-01-09            0                 0                 0                 0
# 2014-01-10            0                 0                 0                 0
# 2014-01-14            0                 0                 0                 0
# 2014-01-15            1                 0                 0                 0
# 2014-01-16            0                 0                 0                 0
#
#             name_アジ唐揚げ南蛮ソース  name_エビフライ  name_カレイの唐揚げ  name_カレイ唐揚げ 甘酢あん  \
# datetime
# 2014-01-09                0           0             0                 0
# 2014-01-10                0           0             0                 0
# 2014-01-14                0           0             0                 0
# 2014-01-15                0           0             0                 0
# 2014-01-16                0           0             0                 0
#
#             name_カレイ唐揚げ夏野菜あん  name_カレイ唐揚げ野菜あんかけ  name_カレイ唐揚げ野菜餡かけ  \
# datetime
# 2014-01-09                 0                  0                 0
# 2014-01-10                 0                  0                 0
# 2014-01-14                 0                  0                 0
# 2014-01-15                 0                  0                 0
# 2014-01-16                 0                  1                 0
#
#             name_カレイ野菜あんかけ  name_キスと野菜の天ぷら  name_キーマカレー  name_ゴーヤチャンプルー  \
# datetime
# 2014-01-09               0               0            0               0
# 2014-01-10               0               0            0               0
# 2014-01-14               0               0            0               0
# 2014-01-15               0               0            0               0
# 2014-01-16               0               0            0               0
#
#             name_サバ焼味噌掛け  name_サーモンのムニエル2色ソース  name_サーモンフライ・タルタル  \
# datetime
# 2014-01-09             0                    0                  0
# 2014-01-10             0                    0                  0
# 2014-01-14             0                    0                  0
# 2014-01-15             0                    0                  0
# 2014-01-16             0                    0                  0
#
#             name_ジャンボチキンカツ  name_ジューシーメンチカツ  name_タンドリーチキン  \
# datetime
# 2014-01-09               0                0              0
# 2014-01-10               0                0              0
# 2014-01-14               0                0              0
# 2014-01-15               0                0              0
# 2014-01-16               0                0              0
#
#             name_チキンのコーンクリーム焼き  name_チキンの辛味噌焼き  name_チキンクリームシチュー  \
# datetime
# 2014-01-09                   0               0                 0
# 2014-01-10                   0               0                 0
# 2014-01-14                   0               0                 0
# 2014-01-15                   0               0                 0
# 2014-01-16                   0               0                 0
#
#             name_チキンステーキ・きのこソース  name_チキンフリカッセ  name_チキン南蛮  \
# datetime
# 2014-01-09                    0              0           0
# 2014-01-10                    0              0           0
# 2014-01-14                    0              0           0
# 2014-01-15                    0              0           0
# 2014-01-16                    0              0           0
#
#             name_チキン香草焼きマスタードソース  name_チャプチェ  name_チンジャオロース  name_チーズハンバーグ  \
# datetime
# 2014-01-09                     0           0              0              0
# 2014-01-10                     0           0              0              0
# 2014-01-14                     0           0              0              0
# 2014-01-15                     0           0              0              0
# 2014-01-16                     0           0              0              0
#
#             name_チーズメンチカツ  name_チーズ入りハンバーグ  name_チーズ入りメンチカツ  name_ハンバーグカレーソース  \
# datetime
# 2014-01-09              0                0                0                 0
# 2014-01-10              0                0                0                 0
# 2014-01-14              0                0                0                 0
# 2014-01-15              0                0                0                 0
# 2014-01-16              0                0                0                 0
#
#             name_ハンバーグケッチャップソース  name_ハンバーグデミソース  name_ハンバーグ和風きのこソース  \
# datetime
# 2014-01-09                    0                0                   0
# 2014-01-10                    0                0                   0
# 2014-01-14                    0                0                   0
# 2014-01-15                    0                0                   0
# 2014-01-16                    0                0                   0
#
#             name_ハンバーグ（デミきのこバター）  name_バーベキューチキン  name_ビーフカレー  name_ビーフシチュー  \
# datetime
# 2014-01-09                     0               0            0             0
# 2014-01-10                     0               0            0             0
# 2014-01-14                     0               0            0             0
# 2014-01-15                     0               0            0             0
# 2014-01-16                     0               0            0             0
#
#             name_ビーフストロガノフ  name_ビーフトマト煮  name_プルコギ  name_ホタテクリ―ムシチュー  \
# datetime
# 2014-01-09               0             0          0                 0
# 2014-01-10               0             0          0                 0
# 2014-01-14               0             0          0                 0
# 2014-01-15               0             0          0                 0
# 2014-01-16               0             0          0                 0
#
#             name_ボローニャ風カツ  name_ポークソテー韓国ソース  name_ポークハヤシ  name_ポーク生姜焼き  \
# datetime
# 2014-01-09              0                 0            0             0
# 2014-01-10              0                 0            0             0
# 2014-01-14              0                 0            0             0
# 2014-01-15              0                 0            0             0
# 2014-01-16              0                 0            0             0
#
#             name_マーボ茄子  name_マーボ豆腐  name_メダイ照り焼  name_メンチカツ  name_ロース甘味噌焼き  \
# datetime
# 2014-01-09           0           0            0           0              0
# 2014-01-10           0           0            0           0              0
# 2014-01-14           0           0            0           0              0
# 2014-01-15           0           0            0           0              0
# 2014-01-16           0           0            0           0              0
#
#             name_八宝菜  name_厚切イカフライ  name_厚切ハムカツ  name_名古屋味噌カツ  \
# datetime
# 2014-01-09         0             0            0             0
# 2014-01-10         0             0            0             0
# 2014-01-14         0             0            0             0
# 2014-01-15         0             0            0             0
# 2014-01-16         0             0            0             0
#
#             name_和風ソースハンバーグ  name_和風ハンバーグ  name_回鍋肉  name_手作りひれかつ  \
# datetime
# 2014-01-09                0             0         0             0
# 2014-01-10                0             0         0             0
# 2014-01-14                0             0         0             0
# 2014-01-15                0             0         0             0
# 2014-01-16                0             0         0             0
#
#             name_手作りひれかつとカレー  name_手作りチキンカツ  name_手作りトンカツ  name_手作りロースカツ  \
# datetime
# 2014-01-09                 0              0             0              0
# 2014-01-10                 0              0             0              1
# 2014-01-14                 0              0             0              0
# 2014-01-15                 0              0             0              0
# 2014-01-16                 0              0             0              0
#
#             name_洋食屋さんのメンチカツ  name_海老クリーミ―クノーデル  name_海老フライとホタテ串カツ  \
# datetime
# 2014-01-09                 0                  0                  0
# 2014-01-10                 0                  0                  0
# 2014-01-14                 0                  0                  0
# 2014-01-15                 0                  0                  0
# 2014-01-16                 0                  0                  0
#
#             name_海老フライタルタル  name_炊き込みご飯  name_牛すき焼き風  name_牛カルビ焼き肉  \
# datetime
# 2014-01-09               0            0            0             0
# 2014-01-10               0            0            0             0
# 2014-01-14               0            0            0             0
# 2014-01-15               0            0            0             0
# 2014-01-16               0            0            0             0
#
#             name_牛スキヤキ  name_牛丼風煮  name_牛肉すき焼き風  name_牛肉コロッケ  name_牛肉ニンニクの芽炒め  \
# datetime
# 2014-01-09           0          0             0            0                0
# 2014-01-10           0          0             0            0                0
# 2014-01-14           0          0             0            0                0
# 2014-01-15           0          0             0            0                0
# 2014-01-16           0          0             0            0                0
#
#             name_牛肉筍煮  name_白身魚のマスタード焼き  name_白身魚の南部焼き  name_白身魚フライ  \
# datetime
# 2014-01-09          0                 0              0            0
# 2014-01-10          0                 0              0            0
# 2014-01-14          0                 0              0            0
# 2014-01-15          0                 0              0            0
# 2014-01-16          0                 0              0            0
#
#             name_白身魚ムニエル  name_白身魚唐揚げ野菜あんかけ  name_白身魚唐揚げ野菜餡かけ  name_筑前煮  \
# datetime
# 2014-01-09             0                  0                 0         0
# 2014-01-10             0                  0                 0         0
# 2014-01-14             0                  0                 0         0
# 2014-01-15             0                  0                 0         0
# 2014-01-16             0                  0                 0         0
#
#             name_肉じゃが  name_肉団子のシチュー  name_肉団子クリームシチュー  name_親子煮  name_豚すき焼き  \
# datetime
# 2014-01-09          0              0                 0         0           0
# 2014-01-10          0              0                 0         0           0
# 2014-01-14          0              0                 0         0           0
# 2014-01-15          0              0                 0         0           0
# 2014-01-16          0              0                 0         0           0
#
#             name_豚の冷しゃぶ  name_豚キムチ炒め  name_豚ロースのピザ風チーズ焼き  name_豚冷シャブ野菜添え  \
# datetime
# 2014-01-09            0            0                   0               0
# 2014-01-10            0            0                   0               0
# 2014-01-14            0            0                   0               0
# 2014-01-15            0            0                   0               0
# 2014-01-16            0            0                   0               0
#
#             name_豚味噌メンチカツ  name_豚肉と玉子の炒め  name_豚肉と茄子のピリ辛炒め  name_豚肉のマスタード焼き  \
# datetime
# 2014-01-09              0              0                 0                0
# 2014-01-10              0              0                 0                0
# 2014-01-14              0              0                 0                0
# 2014-01-15              0              0                 0                0
# 2014-01-16              0              0                 0                0
#
#             name_豚肉の生姜焼き  name_豚肉の胡麻シャブ  name_越冬キャベツのメンチカツ  name_酢豚  \
# datetime
# 2014-01-09             0              0                  0        0
# 2014-01-10             0              0                  0        0
# 2014-01-14             0              0                  0        0
# 2014-01-15             0              0                  0        0
# 2014-01-16             0              0                  0        0
#
#             name_酢豚orカレー  name_青梗菜牛肉炒め  name_青椒肉絲  name_鶏のから揚げねぎ塩炒めソース  \
# datetime
# 2014-01-09             0             0          0                    0
# 2014-01-10             0             0          0                    0
# 2014-01-14             0             0          0                    0
# 2014-01-15             0             0          0                    0
# 2014-01-16             0             0          0                    0
#
#             name_鶏のから揚げスイートチリソース  name_鶏のカッシュナッツ炒め  name_鶏のトマトシチュー  \
# datetime
# 2014-01-09                     0                 0               0
# 2014-01-10                     0                 0               0
# 2014-01-14                     0                 0               0
# 2014-01-15                     0                 0               0
# 2014-01-16                     0                 0               0
#
#             name_鶏のピリ辛焼き  name_鶏のレモンペッパー焼orカレー  name_鶏の味噌漬け焼き  name_鶏の唐揚げ  \
# datetime
# 2014-01-09             0                     0              0           0
# 2014-01-10             0                     0              0           0
# 2014-01-14             0                     0              0           0
# 2014-01-15             0                     0              0           0
# 2014-01-16             0                     0              0           0
#
#             name_鶏の唐揚げおろしソース  name_鶏の塩から揚げ  name_鶏の天ぷら  name_鶏の照り焼きマスタード  \
# datetime
# 2014-01-09                 0             0           0                 0
# 2014-01-10                 0             0           0                 0
# 2014-01-14                 0             0           0                 1
# 2014-01-15                 0             0           0                 0
# 2014-01-16                 0             0           0                 0
#
#             name_鶏の照り焼きマヨ  name_鶏の親子煮  name_鶏チリソース  name_鶏肉とカシューナッツ炒め  \
# datetime
# 2014-01-09              0           0            1                  0
# 2014-01-10              0           0            0                  0
# 2014-01-14              0           0            0                  0
# 2014-01-15              0           0            0                  0
# 2014-01-16              0           0            0                  0
#
#             name_鶏肉のカレー唐揚  name_鶏肉の山賊焼き  event_キャリアアップ支援セミナー  event_ママの会  \
# datetime
# 2014-01-09              0             0                    0           0
# 2014-01-10              0             0                    0           0
# 2014-01-14              0             0                    0           0
# 2014-01-15              0             0                    0           0
# 2014-01-16              0             0                    0           0
#
#             weather_快晴  weather_晴れ  weather_曇  weather_薄曇  weather_雨  \
# datetime
# 2014-01-09           0           0          1           0          0
# 2014-01-10           1           0          0           0          0
# 2014-01-14           0           1          0           0          0
# 2014-01-15           0           0          1           0          0
# 2014-01-16           1           0          0           0          0
#
#             weather_雪  weather_雷電  period_上旬  period_中旬  period_下旬
# datetime
# 2014-01-09          0           0          1          0          0
# 2014-01-10          0           0          1          0          0
# 2014-01-14          0           0          0          1          0
# 2014-01-15          0           0          0          1          0
# 2014-01-16          0           0          0          1          0

# %%
# 改めて、各列にNaNが入っていないか確認
print(dummy_df.isnull().sum()) 
dummy_df.head()
# Out:
# sales                       0
# soldout                     0
# kcal                        0
# payday                      0
# precipitation               0
# temperature                 0
# month                       0
# day                         0
# temperature_diff            0
# temperature_rolling_mean    0
# temperature_pct_change      0
# week_月                      0
# week_木                      0
# week_水                      0
# week_火                      0
# week_金                      0
# name_いか天ぷら                  0
# name_かじきの甘辛煮                0
# name_きのこソースハンバーグ            0
# name_さわら焼味噌掛け               0
# name_さんま辛味焼                 0
# name_たっぷりベーコンフライ            0
# name_ぶりレモンペッパー焼き            0
# name_ますのマスタードソース            0
# name_アジ唐揚げ南蛮ソース             0
# name_エビフライ                  0
# name_カレイの唐揚げ                0
# name_カレイ唐揚げ 甘酢あん            0
# name_カレイ唐揚げ夏野菜あん            0
# name_カレイ唐揚げ野菜あんかけ           0
#                            ..
# name_鶏のから揚げねぎ塩炒めソース         0
# name_鶏のから揚げスイートチリソース        0
# name_鶏のカッシュナッツ炒め            0
# name_鶏のトマトシチュー              0
# name_鶏のピリ辛焼き                0
# name_鶏のレモンペッパー焼orカレー        0
# name_鶏の味噌漬け焼き               0
# name_鶏の唐揚げ                  0
# name_鶏の唐揚げおろしソース            0
# name_鶏の塩から揚げ                0
# name_鶏の天ぷら                  0
# name_鶏の照り焼きマスタード            0
# name_鶏の照り焼きマヨ               0
# name_鶏の親子煮                  0
# name_鶏チリソース                 0
# name_鶏肉とカシューナッツ炒め           0
# name_鶏肉のカレー唐揚               0
# name_鶏肉の山賊焼き                0
# event_キャリアアップ支援セミナー         0
# event_ママの会                  0
# weather_快晴                  0
# weather_晴れ                  0
# weather_曇                   0
# weather_薄曇                  0
# weather_雨                   0
# weather_雪                   0
# weather_雷電                  0
# period_上旬                   0
# period_中旬                   0
# period_下旬                   0
# Length: 157, dtype: int64
#             sales  soldout   kcal  payday  precipitation  temperature  month  \
# datetime
# 2014-01-09    129        1  435.0     0.0            0.0         10.9      1
# 2014-01-10     87        0  440.0     1.0            0.0          5.1      1
# 2014-01-14    129        1  376.0     0.0            0.0          5.8      1
# 2014-01-15    134        0  450.0     0.0            0.0          2.9      1
# 2014-01-16    107        0  415.0     0.0            0.0          7.0      1
#
#             day  temperature_diff  temperature_rolling_mean  \
# datetime
# 2014-01-09    9               1.1                  9.333333
# 2014-01-10   10              -5.8                  8.600000
# 2014-01-14   14               0.7                  7.266667
# 2014-01-15   15              -2.9                  4.600000
# 2014-01-16   16               4.1                  5.233333
#
#             temperature_pct_change  week_月  week_木  week_水  week_火  week_金  \
# datetime
# 2014-01-09                0.112245       0       1       0       0       0
# 2014-01-10               -0.532110       0       0       0       0       1
# 2014-01-14                0.137255       0       0       0       1       0
# 2014-01-15               -0.500000       0       0       1       0       0
# 2014-01-16                1.413793       0       1       0       0       0
#
#             name_いか天ぷら  name_かじきの甘辛煮  name_きのこソースハンバーグ  name_さわら焼味噌掛け  \
# datetime
# 2014-01-09           0             0                 0              0
# 2014-01-10           0             0                 0              0
# 2014-01-14           0             0                 0              0
# 2014-01-15           0             0                 0              0
# 2014-01-16           0             0                 0              0
#
#             name_さんま辛味焼  name_たっぷりベーコンフライ  name_ぶりレモンペッパー焼き  name_ますのマスタードソース  \
# datetime
# 2014-01-09            0                 0                 0                 0
# 2014-01-10            0                 0                 0                 0
# 2014-01-14            0                 0                 0                 0
# 2014-01-15            1                 0                 0                 0
# 2014-01-16            0                 0                 0                 0
#
#             name_アジ唐揚げ南蛮ソース  name_エビフライ  name_カレイの唐揚げ  name_カレイ唐揚げ 甘酢あん  \
# datetime
# 2014-01-09                0           0             0                 0
# 2014-01-10                0           0             0                 0
# 2014-01-14                0           0             0                 0
# 2014-01-15                0           0             0                 0
# 2014-01-16                0           0             0                 0
#
#             name_カレイ唐揚げ夏野菜あん  name_カレイ唐揚げ野菜あんかけ  name_カレイ唐揚げ野菜餡かけ  \
# datetime
# 2014-01-09                 0                  0                 0
# 2014-01-10                 0                  0                 0
# 2014-01-14                 0                  0                 0
# 2014-01-15                 0                  0                 0
# 2014-01-16                 0                  1                 0
#
#             name_カレイ野菜あんかけ  name_キスと野菜の天ぷら  name_キーマカレー  name_ゴーヤチャンプルー  \
# datetime
# 2014-01-09               0               0            0               0
# 2014-01-10               0               0            0               0
# 2014-01-14               0               0            0               0
# 2014-01-15               0               0            0               0
# 2014-01-16               0               0            0               0
#
#             name_サバ焼味噌掛け  name_サーモンのムニエル2色ソース  name_サーモンフライ・タルタル  \
# datetime
# 2014-01-09             0                    0                  0
# 2014-01-10             0                    0                  0
# 2014-01-14             0                    0                  0
# 2014-01-15             0                    0                  0
# 2014-01-16             0                    0                  0
#
#             name_ジャンボチキンカツ  name_ジューシーメンチカツ  name_タンドリーチキン  \
# datetime
# 2014-01-09               0                0              0
# 2014-01-10               0                0              0
# 2014-01-14               0                0              0
# 2014-01-15               0                0              0
# 2014-01-16               0                0              0
#
#             name_チキンのコーンクリーム焼き  name_チキンの辛味噌焼き  name_チキンクリームシチュー  \
# datetime
# 2014-01-09                   0               0                 0
# 2014-01-10                   0               0                 0
# 2014-01-14                   0               0                 0
# 2014-01-15                   0               0                 0
# 2014-01-16                   0               0                 0
#
#             name_チキンステーキ・きのこソース  name_チキンフリカッセ  name_チキン南蛮  \
# datetime
# 2014-01-09                    0              0           0
# 2014-01-10                    0              0           0
# 2014-01-14                    0              0           0
# 2014-01-15                    0              0           0
# 2014-01-16                    0              0           0
#
#             name_チキン香草焼きマスタードソース  name_チャプチェ  name_チンジャオロース  name_チーズハンバーグ  \
# datetime
# 2014-01-09                     0           0              0              0
# 2014-01-10                     0           0              0              0
# 2014-01-14                     0           0              0              0
# 2014-01-15                     0           0              0              0
# 2014-01-16                     0           0              0              0
#
#             name_チーズメンチカツ  name_チーズ入りハンバーグ  name_チーズ入りメンチカツ  name_ハンバーグカレーソース  \
# datetime
# 2014-01-09              0                0                0                 0
# 2014-01-10              0                0                0                 0
# 2014-01-14              0                0                0                 0
# 2014-01-15              0                0                0                 0
# 2014-01-16              0                0                0                 0
#
#             name_ハンバーグケッチャップソース  name_ハンバーグデミソース  name_ハンバーグ和風きのこソース  \
# datetime
# 2014-01-09                    0                0                   0
# 2014-01-10                    0                0                   0
# 2014-01-14                    0                0                   0
# 2014-01-15                    0                0                   0
# 2014-01-16                    0                0                   0
#
#             name_ハンバーグ（デミきのこバター）  name_バーベキューチキン  name_ビーフカレー  name_ビーフシチュー  \
# datetime
# 2014-01-09                     0               0            0             0
# 2014-01-10                     0               0            0             0
# 2014-01-14                     0               0            0             0
# 2014-01-15                     0               0            0             0
# 2014-01-16                     0               0            0             0
#
#             name_ビーフストロガノフ  name_ビーフトマト煮  name_プルコギ  name_ホタテクリ―ムシチュー  \
# datetime
# 2014-01-09               0             0          0                 0
# 2014-01-10               0             0          0                 0
# 2014-01-14               0             0          0                 0
# 2014-01-15               0             0          0                 0
# 2014-01-16               0             0          0                 0
#
#             name_ボローニャ風カツ  name_ポークソテー韓国ソース  name_ポークハヤシ  name_ポーク生姜焼き  \
# datetime
# 2014-01-09              0                 0            0             0
# 2014-01-10              0                 0            0             0
# 2014-01-14              0                 0            0             0
# 2014-01-15              0                 0            0             0
# 2014-01-16              0                 0            0             0
#
#             name_マーボ茄子  name_マーボ豆腐  name_メダイ照り焼  name_メンチカツ  name_ロース甘味噌焼き  \
# datetime
# 2014-01-09           0           0            0           0              0
# 2014-01-10           0           0            0           0              0
# 2014-01-14           0           0            0           0              0
# 2014-01-15           0           0            0           0              0
# 2014-01-16           0           0            0           0              0
#
#             name_八宝菜  name_厚切イカフライ  name_厚切ハムカツ  name_名古屋味噌カツ  \
# datetime
# 2014-01-09         0             0            0             0
# 2014-01-10         0             0            0             0
# 2014-01-14         0             0            0             0
# 2014-01-15         0             0            0             0
# 2014-01-16         0             0            0             0
#
#             name_和風ソースハンバーグ  name_和風ハンバーグ  name_回鍋肉  name_手作りひれかつ  \
# datetime
# 2014-01-09                0             0         0             0
# 2014-01-10                0             0         0             0
# 2014-01-14                0             0         0             0
# 2014-01-15                0             0         0             0
# 2014-01-16                0             0         0             0
#
#             name_手作りひれかつとカレー  name_手作りチキンカツ  name_手作りトンカツ  name_手作りロースカツ  \
# datetime
# 2014-01-09                 0              0             0              0
# 2014-01-10                 0              0             0              1
# 2014-01-14                 0              0             0              0
# 2014-01-15                 0              0             0              0
# 2014-01-16                 0              0             0              0
#
#             name_洋食屋さんのメンチカツ  name_海老クリーミ―クノーデル  name_海老フライとホタテ串カツ  \
# datetime
# 2014-01-09                 0                  0                  0
# 2014-01-10                 0                  0                  0
# 2014-01-14                 0                  0                  0
# 2014-01-15                 0                  0                  0
# 2014-01-16                 0                  0                  0
#
#             name_海老フライタルタル  name_炊き込みご飯  name_牛すき焼き風  name_牛カルビ焼き肉  \
# datetime
# 2014-01-09               0            0            0             0
# 2014-01-10               0            0            0             0
# 2014-01-14               0            0            0             0
# 2014-01-15               0            0            0             0
# 2014-01-16               0            0            0             0
#
#             name_牛スキヤキ  name_牛丼風煮  name_牛肉すき焼き風  name_牛肉コロッケ  name_牛肉ニンニクの芽炒め  \
# datetime
# 2014-01-09           0          0             0            0                0
# 2014-01-10           0          0             0            0                0
# 2014-01-14           0          0             0            0                0
# 2014-01-15           0          0             0            0                0
# 2014-01-16           0          0             0            0                0
#
#             name_牛肉筍煮  name_白身魚のマスタード焼き  name_白身魚の南部焼き  name_白身魚フライ  \
# datetime
# 2014-01-09          0                 0              0            0
# 2014-01-10          0                 0              0            0
# 2014-01-14          0                 0              0            0
# 2014-01-15          0                 0              0            0
# 2014-01-16          0                 0              0            0
#
#             name_白身魚ムニエル  name_白身魚唐揚げ野菜あんかけ  name_白身魚唐揚げ野菜餡かけ  name_筑前煮  \
# datetime
# 2014-01-09             0                  0                 0         0
# 2014-01-10             0                  0                 0         0
# 2014-01-14             0                  0                 0         0
# 2014-01-15             0                  0                 0         0
# 2014-01-16             0                  0                 0         0
#
#             name_肉じゃが  name_肉団子のシチュー  name_肉団子クリームシチュー  name_親子煮  name_豚すき焼き  \
# datetime
# 2014-01-09          0              0                 0         0           0
# 2014-01-10          0              0                 0         0           0
# 2014-01-14          0              0                 0         0           0
# 2014-01-15          0              0                 0         0           0
# 2014-01-16          0              0                 0         0           0
#
#             name_豚の冷しゃぶ  name_豚キムチ炒め  name_豚ロースのピザ風チーズ焼き  name_豚冷シャブ野菜添え  \
# datetime
# 2014-01-09            0            0                   0               0
# 2014-01-10            0            0                   0               0
# 2014-01-14            0            0                   0               0
# 2014-01-15            0            0                   0               0
# 2014-01-16            0            0                   0               0
#
#             name_豚味噌メンチカツ  name_豚肉と玉子の炒め  name_豚肉と茄子のピリ辛炒め  name_豚肉のマスタード焼き  \
# datetime
# 2014-01-09              0              0                 0                0
# 2014-01-10              0              0                 0                0
# 2014-01-14              0              0                 0                0
# 2014-01-15              0              0                 0                0
# 2014-01-16              0              0                 0                0
#
#             name_豚肉の生姜焼き  name_豚肉の胡麻シャブ  name_越冬キャベツのメンチカツ  name_酢豚  \
# datetime
# 2014-01-09             0              0                  0        0
# 2014-01-10             0              0                  0        0
# 2014-01-14             0              0                  0        0
# 2014-01-15             0              0                  0        0
# 2014-01-16             0              0                  0        0
#
#             name_酢豚orカレー  name_青梗菜牛肉炒め  name_青椒肉絲  name_鶏のから揚げねぎ塩炒めソース  \
# datetime
# 2014-01-09             0             0          0                    0
# 2014-01-10             0             0          0                    0
# 2014-01-14             0             0          0                    0
# 2014-01-15             0             0          0                    0
# 2014-01-16             0             0          0                    0
#
#             name_鶏のから揚げスイートチリソース  name_鶏のカッシュナッツ炒め  name_鶏のトマトシチュー  \
# datetime
# 2014-01-09                     0                 0               0
# 2014-01-10                     0                 0               0
# 2014-01-14                     0                 0               0
# 2014-01-15                     0                 0               0
# 2014-01-16                     0                 0               0
#
#             name_鶏のピリ辛焼き  name_鶏のレモンペッパー焼orカレー  name_鶏の味噌漬け焼き  name_鶏の唐揚げ  \
# datetime
# 2014-01-09             0                     0              0           0
# 2014-01-10             0                     0              0           0
# 2014-01-14             0                     0              0           0
# 2014-01-15             0                     0              0           0
# 2014-01-16             0                     0              0           0
#
#             name_鶏の唐揚げおろしソース  name_鶏の塩から揚げ  name_鶏の天ぷら  name_鶏の照り焼きマスタード  \
# datetime
# 2014-01-09                 0             0           0                 0
# 2014-01-10                 0             0           0                 0
# 2014-01-14                 0             0           0                 1
# 2014-01-15                 0             0           0                 0
# 2014-01-16                 0             0           0                 0
#
#             name_鶏の照り焼きマヨ  name_鶏の親子煮  name_鶏チリソース  name_鶏肉とカシューナッツ炒め  \
# datetime
# 2014-01-09              0           0            1                  0
# 2014-01-10              0           0            0                  0
# 2014-01-14              0           0            0                  0
# 2014-01-15              0           0            0                  0
# 2014-01-16              0           0            0                  0
#
#             name_鶏肉のカレー唐揚  name_鶏肉の山賊焼き  event_キャリアアップ支援セミナー  event_ママの会  \
# datetime
# 2014-01-09              0             0                    0           0
# 2014-01-10              0             0                    0           0
# 2014-01-14              0             0                    0           0
# 2014-01-15              0             0                    0           0
# 2014-01-16              0             0                    0           0
#
#             weather_快晴  weather_晴れ  weather_曇  weather_薄曇  weather_雨  \
# datetime
# 2014-01-09           0           0          1           0          0
# 2014-01-10           1           0          0           0          0
# 2014-01-14           0           1          0           0          0
# 2014-01-15           0           0          1           0          0
# 2014-01-16           1           0          0           0          0
#
#             weather_雪  weather_雷電  period_上旬  period_中旬  period_下旬
# datetime
# 2014-01-09          0           0          1          0          0
# 2014-01-10          0           0          1          0          0
# 2014-01-14          0           0          0          1          0
# 2014-01-15          0           0          0          1          0
# 2014-01-16          0           0          0          1          0

# %%
# 出来たデータをutf-8で保存する
dummy_df.to_csv('../../Data/processed_datamart.csv', encoding='utf-8')
